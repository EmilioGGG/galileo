# %% [markdown]
# # Ensayo SVM

# %% [markdown]
# ## hipótesis de SVM
# Dado que SVM no genera resultados probabilisticos, nos podemos basar en la expresión que nos da un regresion lineal, esto nos da la siguiente hipótesis:
# ![imagen.png](attachment:17544cb2-583c-4452-85bb-3d654fe9fedd.png)
#
# ## función de costo
# Esta es conocida como bisagra, una forma de entenderla facilmente es comparandola con una función de costo de la regresión logistica, ya qye son similares:
# ![imagen.png](attachment:542d7095-0a7d-4eda-aedd-d1f06a16aeb7.png)
#
# ## Algoritmo de aprendizaje/entrenamiento
# La forma de entrenamiento es que este algoritmo se busca minimizar la magnitud del parametro de pesos y el segundo termino penaliza a las observaciones que no quedan del lado correcto del entrenamiento, donde se busca optimziar la funcion de costo:
# ![imagen.png](attachment:7b186f72-de50-4911-b2f8-3b13e3adf905.png)
#
# ## Propiedades, similitudes, diferencias ,ventajas y desventajas sobre otros algoritmos y modelos.
#
# Entre las ventajas tenemos:
#
# * Eficaz en espacios de grandes dimensiones.
# * Todavía eficaz en casos donde el número de dimensiones es mayor que el número de muestras.
# * Utiliza un subconjunto de puntos de entrenamiento en la función de decisión (llamada vectores de soporte), por lo que también es eficiente en memoria.
# * Versátil: se pueden especificar diferentes funciones del núcleo para la función de decisión. Se proporcionan kernels comunes, pero también es posible especificar kernels personalizados.
#
#
# Entre las desventajas tenemos:
#
# * Si el número de características es mucho mayor que el número de muestras, evite el exceso de ajuste al elegir las funciones del Kernel y el término de regularización es crucial.
# * Los SVMs no proporcionan directamente estimaciones de probabilidad, éstas se calculan utilizando una validación cruzada quíntuple (véase Partituras y probabilidades, más abajo).
#
# ## Kernel-trick/basis functions
# Este nos da la similitud entre pares de puntos:
#
# ![imagen.png](attachment:af102d02-c502-4ddb-b035-3001c32e7959.png)
#
#
# La idea basica de este es que cada observacion del entrenamiento nos da una nueva featgure del espacio
